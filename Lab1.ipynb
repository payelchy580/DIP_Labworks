# %% [markdown]
# <a href="https://colab.research.google.com/github/payelchy580/DIP_Labworks/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
imagefolder = "/content/drive/MyDrive/Colab Notebooks/DIP Lab Works/rabbit"

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# List all files in the folder
images = os.listdir(imagefolder)

# Display one image
img_path = os.path.join(imagefolder, images[200])
img = mpimg.imread(img_path)

plt.imshow(img)
plt.axis('off')
plt.title('Sample Image from Google Drive')
plt.show()
# Get dimensions
height, width, channels = img.shape

# Get image size in bytes
image_size = img.size  # total number of pixels × channels
image_dtype = img.dtype  # data type (usually uint8)

print("Image Details")
print(f"Width: {width} pixels")
print(f"Height: {height} pixels")
print(f"Image Resolution (in pixels): {image_size}")
print(f"Data Type: {image_dtype}")
# Out:
# Image Details
# Width: 300 pixels
# Height: 300 pixels
# Image Resolution (in pixels): 270000
# Data Type: uint8
